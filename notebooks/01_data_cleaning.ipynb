# %% [markdown]
# # 数据清洗与探索性分析
#
# 本 Notebook 用于 Pandas 数据清洗与探索性数据分析 (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 加载原始数据
df = pd.read_csv('../data/raw/boss_raw.csv')
df.head()

# %%
# 数据概览
df.info()
df.describe()

# %%
# 缺失值分析
df.isnull().sum()

# %%
# 数据清洗逻辑
# TODO: 实现具体的数据清洗步骤

# %%
# 保存清洗后的数据
# df.to_csv('../data/processed/cleaned_data.csv', index=False)
